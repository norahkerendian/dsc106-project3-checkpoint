# %%
import pandas as pd

# %%
data = pd.read_csv("metadata.csv")
list(data.columns)
# Out:
# ['Municipality code',
#  'Municipality',
#  'Population2007',
#  'Population2008',
#  'Population2009',
#  'Population2010',
#  'Population2011',
#  'Population2012',
#  'Population2013',
#  'Population2014',
#  'Population2015',
#  'Population2016',
#  'Population2017',
#  'Population2018',
#  'Population2019',
#  'Cases2007',
#  'Cases2008',
#  'Cases2009',
#  'Cases2010',
#  'Cases2011',
#  'Cases2012',
#  'Cases2013',
#  'Cases2014',
#  'Cases2015',
#  'Cases2016',
#  'Cases2017',
#  'Cases2018',
#  'Cases2019',
#  'Age0-4(%)',
#  'Age5-14(%)',
#  'Age15-29(%)',
#  'Age>30(%)',
#  'AfrocolombianPopulation(%)',
#  'IndianPopulation(%)',
#  'PeoplewithDisabilities(%)',
#  'Peoplewhocannotreadorwrite(%)',
#  'Secondary/HigherEducation(%)',
#  'Employedpopulation(%)',
#  'Unemployedpopulation(%)',
#  'Peopledoinghousework(%)',
#  'Retiredpeople(%)',
#  'Men(%)',
#  'Women(%)',
#  'Householdswithoutwateraccess(%)',
#  'Householdswithoutinternetaccess(%)',
# ...

# %%
len(data['Municipality code'].unique())
# for value in data['Municipality'].unique():
#     print(value)
# Out:
# 1121

# %% [markdown]
# want to create some sort of plot that looks at the trend of something over time (2007 - 2019)

# %%
data['Population2019'].median()
# Out:
# np.float64(12817.0)

# %%
# find duplicate rows based on the Municipality column
data[data.duplicated(subset=['Municipality'], keep=False)].sort_values(by='Municipality').loc[data['Population2019'] > 12800]
# Out:
#       Municipality code Municipality  Population2007  Population2008  \
# 642               44035      Albania           18080           18743
# 363               19050      Argelia           24286           24642
# 819               63001      Armenia          289265          289953
# 364               19075       Balboa           23786           23938
# 16                 5079      Barbosa           44052           44568
# ...                 ...          ...             ...             ...
# 396               19780       Suárez           19549           19840
# 816               54820       Toledo           16398           16616
# 193               13873   Villanueva           18841           19459
# 655               44874   Villanueva           24873           26037
# 1072              85440   Villanueva           23247           23961
#
#       Population2009  Population2010  Population2011  Population2012  \
# ...

# %%
# i could do a play on the line plot that the name generator had. i could just focus on population or the cases and see how it has changed over time for each municipality
# and the interactive aspect would be that you could select a municipality and see how its population has changed over time

# i only want to focus on the columns before 'Age0-4(%)', this includes the municipality, population, and cases columns
data.iloc[:, :data.columns.get_loc('Age0-4(%)')]
# Out:
#       Municipality code    Municipality  Population2007  Population2008  \
# 0                  5001        Medellín         2286126         2309689
# 1                  5002       Abejorral           20643           20944
# 2                  5004        Abriaquí            2261            2290
# 3                  5021      Alejandría            3935            4020
# 4                  5030           Amagá           27996           28331
# ...                 ...             ...             ...             ...
# 1116              97889        Yavaraté             555             693
# 1117              99001  Puerto Carreño           13742           14559
# 1118              99524    La Primavera            5190            5784
# 1119              99624   Santa Rosalía            3167            3378
# 1120              99773        Cumaribo           24342           26882
#
#       Population2009  Population2010  Population2011  Population2012  \
# ...
